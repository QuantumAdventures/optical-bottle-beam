# %%
import numpy as np
import pandas as pd
from scipy.io import loadmat
from matplotlib import pyplot as plt
from scipy.optimize import curve_fit
from sklearn.metrics import mean_squared_error
import os

plt.rcParams["figure.autolayout"] = True
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 2
plt.rcParams.update({'font.size': 15})

# %%
def Fx(x, k1, k2, k3):
    return k1*np.power(x,3)+k2*np.power(x,1)+k3

def Fy(y, k1, k2, k3):
    return k1*np.power(x,3)+k2*np.power(x,1)+k3

def Fz(z, k1, k2):
    return k1*z + k2

# %%
mat_file = loadmat('../simulations/error_analysis/57-170.mat')
mat_file
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Sun Nov 13 19:43:19 2022',
#  '__version__': '1.0',
#  '__globals__': [],
#  'fr': array([[-2.94651307e-12, -3.00746945e-12, -3.06796216e-12, ...,
#           3.06796216e-12,  3.00746945e-12,  2.94651307e-12],
#         [-3.01690028e-12, -3.07816061e-12, -3.13887812e-12, ...,
#           3.13887812e-12,  3.07816061e-12,  3.01690028e-12],
#         [ 5.62379777e-13,  5.84579507e-13,  6.07310361e-13, ...,
#           6.07310361e-13,  5.84579507e-13,  5.62379777e-13]]),
#  'fz': array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.38015645e-12,  2.36857705e-12,  2.35701522e-12, ...,
#          -5.78847396e-13, -5.80312262e-13, -5.81749621e-13]]),
#  'r': array([[-9.75000000e-07, -9.71092184e-07, -9.67184369e-07, ...,
#           9.67184369e-07,  9.71092184e-07,  9.75000000e-07],
#         [-9.75000000e-07, -9.71092184e-07, -9.67184369e-07, ...,
#           9.67184369e-07,  9.71092184e-07,  9.75000000e-07],
#         [ 2.54155417e-07,  2.54155417e-07,  2.54155417e-07, ...,
#           2.54155417e-07,  2.54155417e-07,  2.54155417e-07]]),
#  'z': array([[-0.00000000e+00, -0.00000000e+00, -0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-0.00000000e+00, -0.00000000e+00, -0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-9.75000000e-07, -9.71092184e-07, -9.67184369e-07, ...,
#           9.67184369e-07,  9.71092184e-07,  9.75000000e-07]])}

# %%
def load_data(filepath):
    mat_file = loadmat(filepath)
    fr = mat_file['fr']
    fz = mat_file['fz']
    r = mat_file['r']
    z = mat_file['z']
    x = 10**8*r[0,inf:sup]
    y = 10**8*r[1,inf:sup]
    z = 10**8*z[2,inf:sup]
    fx = 10**14*fr[0,inf:sup]
    fy = 10**14*fr[1,inf:sup]
    fz = 10**14*fz[2,inf:sup]
    return x, y, z, fx, fy, fz


def compute_error(function, x_axis, function_values, p0_size):
    params, _ = curve_fit(function, x_axis, function_values, p0=np.random.rand(p0_size))
    fitted_curve = function(x_axis, *params)
    return np.sqrt(np.power((fitted_curve - function_values),2).mean())/np.sqrt(np.power(function_values,2).mean())

# %%
simulations_path = '../simulations/error_analysis'
errors, axis, NAs, radiuss = [], [], [], []
for file in os.listdir(simulations_path):
    inf = 220
    sup = 280
    if file.split('.')[-1] != 'mat':
        continue
    splitted = file.split('-')
    NA = float(splitted[0])
    radius = float(splitted[1][:-3])
    radiuss.append(radius)
    NAs.append(NA)
    x, y, z, fx, fy, fz = load_data(f'{simulations_path}/{file}')
    error = compute_error(Fx, x, fx, 3)
    errors.append(error)
    axis.append('x')
    error = compute_error(Fy, y, fy, 3)
    errors.append(error)
    radiuss.append(radius)
    NAs.append(NA)
    axis.append('y')
    error = compute_error(Fz, z, fz, 2)
    errors.append(error)
    axis.append('z')
    radiuss.append(radius)
    NAs.append(NA)
# Out:
# /Users/oscarkremer/miniconda3/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
np.array(errors).mean()
# Out:
# 0.004984236812950024

# %%
df = pd.DataFrame()
df['na'] = NAs
df['radius'] = radiuss
df['error'] = errors
df['axis'] = axis

# %%
grouped_df = df.groupby(by=['na', 'radius'], as_index=False).mean()
grouped_df.head(3)
# Out:
#      na  radius     error
# 0  40.0    50.0  0.000625
# 1  40.0    70.0  0.000509
# 2  40.0   350.0  0.000733

# %%
df['na'].unique()
na_plot = np.arange(40, 62, 2).astype(int)

# %%
legends = []
grouped_df = grouped_df.sort_values(by=['na'])
markers = ['']
linestyle = ['-', '-.', ':', '--', '-', '-', '-', '-', '-', '-','-']
markers = ['', '', '', '', '*', 'p', '^', 'v', 'D', 's', 'o', 'x']
index = 0
for na in grouped_df['na'].unique():
    if int(na) in na_plot:
        select_df = grouped_df[grouped_df['na']==na]
        select_df = select_df.sort_values(by=['radius'])
        plt.plot(select_df['radius'].values, 100*select_df['error'].values, 
                 linestyle=linestyle[index], marker=markers[index], linewidth=2, markersize=6, alpha=0.5)
#        legends.append('{:.2f}'.format(na/100))
        index += 1
plt.plot(575, 0.55, 'ko')
#plt.plot(select_df['radius'].values, len(select_df['radius'].values)*[0.55], linestyle='--', 
#            color='k', linewidth=0.4)
#plt.plot(len(select_df['radius'].values)*[575], np.linspace(0, 1.5, len(select_df['radius'].values)), linestyle='--', 
#            color='k', linewidth=0.4)
#legends.append('Experiment')
plt.grid()
plt.ylabel(r'$RMSE_{avg}\,(\%)$')
plt.xlabel(r'$R\,(nm)$')
#plt.legend(legends, title='NA')
plt.savefig('error_plot.pdf', dpi=300)
plt.show()
legends, linestyle, markers
# Out:
# ([],
#  ['-', '-.', ':', '--', '-', '-', '-', '-', '-', '-', '-'],
#  ['', '', '', '', '*', 'p', '^', 'v', 'D', 's', 'o', 'x'])
